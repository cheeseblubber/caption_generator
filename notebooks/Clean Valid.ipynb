# %%
import skimage
import skimage.io
import scipy.misc
import os

path ='/home/ubuntu/workspace/ImageCaptioning.pytorch/valid/'

for root, dirs, files in os.walk(path, topdown=False):
    for file in files:
        full_path = os.path.join(path, file)
        try:
            skimage.io.imread(full_path)
        except:
            print("Failed on:")
            print(file)
# Out:
# Failed on:
# B01MQ290AG.jpg

# %%
images = ["B01LYBXXFU.jpg",
"B01N9HNYDP.jpg",
"B071CKRTK9.jpg",
"B073PRJB5J.jpg",
"B0751GJBWK.jpg",
"B076BBR19H.jpg",
"B0784X41SW.jpg",
"B009VUJASI.jpg",
"B00OSRVR3U.jpg",
"B01627G32I.jpg",
"B01EYYQR18.jpg",
"B01LYC3IRU.jpg",
"B01N9HWIYY.jpg",
"B071CKTKHD.jpg",
"B073PRWQ7M.jpg",
"B0751JRY7Z.jpg",
"B076BCRFBJ.jpg",
"B0784X7FXJ.jpg",
"B009W1KN3M.jpg",
"B00OTHSB7Y.jpg",
"B016341VMM.jpg",
"B01EZGZWIE.jpg",
"B01LYCAWYR.jpg",
"B01N9KH8HT.jpg",
"B071CN43SJ.jpg",
"B073PS1WQY.jpg",
"B0751K274J.jpg",
"B076BCVML9.jpg",
"B0784Y245D.jpg",
"B009X2SIKK.jpg",
"B00OTZW56Y.jpg",
"B016406HWY.jpg",
"B01EZJRAJU.jpg",
"B01LYDD533.jpg",
"B01N9N5OEL.jpg",
"B071CQL6RP.jpg",
"B073PVQS5D.jpg",
"B0751KW8JP.jpg",
"B076BDK15Y.jpg",
"B0784Z2S7L.jpg",
"B009XREY7Q.jpg",
"B00OV7U94K.jpg",
"B0164W7V4A.jpg",
"B01EZWOGSU.jpg",
"B01LYERJU4.jpg",
"B01N9O264T.jpg",
"B071CRSWSC.jpg",
"B073PVSP8L.jpg",
"B0751LXLGH.jpg",
"B076BHCLY1.jpg",
"B07858FD1C.jpg",
"B009YDJCVC.jpg",
"B00OV7URNI.jpg",
"B0164YD5WU.jpg",
"B01F001WK6.jpg",
"B01LYEUBHD.jpg",
"B01N9SF2ZQ.jpg",
"B071CV14SJ.jpg",
"B073PVTSMF.jpg",
"B0751XK7S5.jpg",
"B076BHKZBC.jpg",
"B0785FCGWG.jpg",
"B009ZREMEY.jpg",
"B00OVA7WMO.jpg",
"B0165C9FO8.jpg",
"B01F04SJOE.jpg",
"B01LYGLTJ5.jpg",
"B01N9SWQ74.jpg",
"B071CV9D29.jpg",
"B073PWKVTP.jpg",
"B0751Z1XSP.jpg",
"B076BHMC5C.jpg",
"B0785HDZKY.jpg",
"B009ZRTE0G.jpg",
"B00OXS2S4G.jpg",
"B0166PQ3TE.jpg",
"B01F06C52E.jpg",
"B01LYHBIUT.jpg",
"B01N9TLWHA.jpg",
"B071CVVSXG.jpg",
"B073PWSPKY.jpg",
"B07523RK3S.jpg",
"B076BPQ2V1.jpg",
"B0785NCY9H.jpg",
"B009ZS6700.jpg",
"B00OZ1HPS0.jpg",
"B0166QKPDS.jpg",
"B01F06HOKW.jpg",
"B01LYHPFQ1.jpg"
         ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dbf9182378c4> in <module>()
#      99
#     100     img = img.astype('float32')/255.0
# --> 101     img = torch.from_numpy(img.transpose([2,0,1])).cuda()
#     102     img = Variable(preprocess(img), volatile=True)
#     103
#
# NameError: name 'torch' is not defined

# %%
import torch
from datetime import datetime
from torch.autograd import Variable
from torchvision import transforms as trn
import scipy.misc
import sys
sys.path.append("/home/ubuntu/workspace/ImageCaptioning.pytorch")
preprocess = trn.Compose([
        #trn.ToTensor(),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
from misc.resnet_utils import myResnet
import misc.resnet
my_resnet = getattr(misc.resnet, 'resnet101')()
#self.my_resnet.load_state_dict(torch.load('./data/imagenet_weights/'+self.cnn_model+'.pth'))
my_resnet.load_state_dict(torch.load('/home/ubuntu/workspace/pth_style/'+ 'resnet101'+'.pth'))
my_resnet = myResnet(my_resnet)
my_resnet.cuda()
my_resnet.eval()
# Out:
# myResnet(
#   (resnet): ResNet(
#     (conv1): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), dilation=(1, 1))
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d (64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#         (conv3): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#         (relu): ReLU(inplace)
#         (downsample): Sequential(
#           (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
start = datetime.now()

for image in images:
    img = skimage.io.imread(path + image)
    if len(img.shape) == 2:
        img = img[:,:,np.newaxis]
        img = np.concatenate((img, img, img), axis=2)

    img = img.astype('float32')/255.0
    img = torch.from_numpy(img.transpose([2,0,1])).cuda()
    img = Variable(preprocess(img), volatile=True)
#     time_start = datetime.now()
    tmp_fc, tmp_att = my_resnet(img)
#     end_time = datetime.now()
#     print("resnet is taking {}", (end_time - time_start).total_seconds())

    
end = datetime.now()
(end - start).total_seconds()
# Out:
# 12.983706

# %%
(end - start).total_seconds()
# Out:
# 0.472647
